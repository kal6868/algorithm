# %% [markdown]
# # 수열

# %% [markdown]
# ## 문제

# %%
from IPython.display import Image

# %% [markdown]
# * 매일 아침 9시에 학교에서 측정한 온도가 어떤 정수의 수열로 주어졌을 때, 연속적인 며칠 동안의 온도의 합이 가장 큰 값을 알아보고자 한다.

# %% [markdown]
# * 예를 들어, 아래와 같이 10일 간의 온도가 주어졌을 때,

# %% [markdown]
# * 3 -2 -4 -9 0 3 7 13 8 -3

# %% [markdown]
# * 모든 연속적인 이틀간의 온도의 합은 아래와 같다.

# %%
Image('../image/2599_수열_1.png')

# %% [markdown]
# * 이때, 온도의 합이 가장 큰 값은 21이다.

# %% [markdown]
# * 또 다른 예로 위와 같은 온도가 주어졌을 때, 모든 연속적인 5일 간의 온도의 합은 아래와 같으며,

# %%
Image('../image/2599_수열_2.png')

# %% [markdown]
# * 이때, 온도의 합이 가장 큰 값은 31이다.

# %% [markdown]
# * 매일 측정한 온도가 정수의 수열로 주어졌을 때, 연속적인 며칠 동안의 온도의 합이 가장 큰 값을 계산하는 프로그램을 작성하시오.

# %% [markdown]
# ## 입력

# %% [markdown]
# * 첫째 줄에는 두 개의 정수 N과 K가 한 개의 공백을 사이에 두고 순서대로 주어진다. 첫 번째 정수 N은 온도를 측정한 전체 날짜의 수이다. N은 2 이상 100,000 이하이다. 두 번째 정수 K는 합을 구하기 위한 연속적인 날짜의 수이다. K는 1과 N 사이의 정수이다. 둘째 줄에는 매일 측정한 온도를 나타내는 N개의 정수가 빈칸을 사이에 두고 주어진다. 이 수들은 모두 -100 이상 100 이하이다.

# %% [markdown]
# ## 출력

# %% [markdown]
# * 첫째 줄에는 입력되는 온도의 수열에서 연속적인 K일의 온도의 합이 최대가 되는 값을 출력한다.

# %% [markdown]
# ## Code

# %%
# 2559_수열 (누적 합) (시간 초과)
import sys
submit = False

input = sys.stdin.readline if submit else input

def solution():
    N, K = map(int, input().split())
    numbers = list(map(int, input().split()))

    max_temp = 0
    for i in range(len(numbers) - K + 1):
        temp = sum(numbers[i:i + K])
        if temp > max_temp:
            max_temp = temp

    print(max_temp)

# %%
# 2559_수열 (누적 합)
import sys
submit = False

input = sys.stdin.readline if submit else input

N, K = map(int, input().split())
numbers = list(map(int, input().split()))

temps = [sum(numbers[:K])]
for i in range(1, len(numbers) - K + 1):
    temp = temps[-1] + numbers[i + K - 1] - numbers[i - 1]
    temps.append(temp)
print(max(temps))

# %%
solution()
# Out:
# 21

# %%
solution()
# Out:
# 31

# %% [markdown]
# ## Note

# %% [markdown]
# ### 풀이 1
#
# * 1. 0 ~ K까지의 합을 초기값으로 설정하여 List에 저장해두고 0번 index의 값을 빼고 K + 1을 값을 더해 List에 추가한다.
# * 2. List에 저장된 값 중 최대값을 출력한다.

# %% [markdown]
# ### 풀이 2
#
# * 1. 0 ~ K까지의 합을 초기값으로 설정하여 List(temps)에 저장해두고 0번 index의 값을 빼고 K + 1을 값을 더해 List에 추가한다.
#     * ex. numbers = [3, -2, -4, -9, 0, 3, 7, 13, 8, -3]
#     * 1\) 처음 5일간의 합은 -12 이므로 이를 temps에 저장한다
#     * 2\) 둘째 날 부터 시작한 5일간의 합은 -12에서 3을 빼고(index: 0) 3을 더한(index: 5) -12이므로 이를 List에 저장한다.
#     * 3\) 셋째 날 부터 시작한 5일간의 합은 -12에서 -2를 빼고(index: 1) 7일 더한 (index: 6) -3이므로 이를 List에 저장한다.
#     * 4\) for 반복문의 i가 5가 될때까지 1)~3)을 반복한다.
#
# * 2. List에 저장된 값 중 최대값을 출력한다.

# %% [markdown]
# https://www.acmicpc.net/problem/2559
