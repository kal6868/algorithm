# %% [markdown]
# # 안테나

# %% [markdown]
# ## 문제

# %% [markdown]
# * 일직선 상의 마을에 여러 채의 집이 위치해 있다. 이중에서 특정 위치의 집에 특별히 한 개의 안테나를 설치하기로 결정했다. 효율성을 위해 안테나로부터 모든 집까지의 거리의 총 합이 최소가 되도록 설치하려고 한다. 이 때 안테나는 집이 위치한 곳에만 설치할 수 있고, 논리적으로 동일한 위치에 여러 개의 집이 존재하는 것이 가능하다.

# %% [markdown]
# * 집들의 위치 값이 주어질 때, 안테나를 설치할 위치를 선택하는 프로그램을 작성하시오.

# %% [markdown]
# * 예를 들어 N=4이고, 각 위치가 1, 5, 7, 9일 때를 가정하자.

# %%
from IPython.display import Image
Image('../image/18310_안테나.jpg')

# %% [markdown]
# * 이 경우 5의 위치에 설치했을 때, 안테나로부터 모든 집까지의 거리의 총 합이 (4+0+2+4)=10으로, 최소가 된다.

# %% [markdown]
# ## 입력

# %% [markdown]
# * 첫째 줄에 집의 수 N이 자연수로 주어진다. (1≤N≤200,000) 둘째 줄에 N채의 집에 위치가 공백을 기준으로 구분되어 1이상 100,000이하의 자연수로 주어진다.

# %% [markdown]
# ## 출력

# %% [markdown]
# * 첫째 줄에 안테나를 설치할 위치의 값을 출력한다. 단, 안테나를 설치할 수 있는 위치 값으로 여러 개의 값이 도출될 경우 가장 작은 값을 출력한다.

# %% [markdown]
# ## Code

# %%
import sys
def solution():
    N = int(input())
    a = list(map(int, input().split()))
    a.sort()
    answer = a[(len(a)-1)//2]
    print(answer)

# %% [markdown]
# ## 예제입력 - 출력

# %%
solution()
# Out:
# 5

# %% [markdown]
# ## Note

# %% [markdown]
# * 집의 위치를 정렬 후 거리의 총 합이 구한 후, 거리와 집 위치를 기준으로해서 정렬한 뒤 정답을 찾으면 계산 시간이 너무 오래 걸리게 된다.
# * 집의 위치를 정렬 후, 집의 총 개수가 홀수면 중앙값을 구하고 총 개수가 짝수면 두개의 중앙값 중 더 작은 위치의 중앙값을 구하면 된다.
# * 다만, index는 0부터 시작이므로, 총 개수에서 1을 뺀 뒤 2로 나눈 몫을 찾는다.

# %% [markdown]
# https://www.acmicpc.net/problem/18310
